# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# - Name: **Winston Liang**
# - Occupation: Research Scientist at Rio Tinto

# %% [markdown]
# *I am taking data science course because I would like utilities the skills to help me to achieve better career outcomes.*

# %% [markdown]
# ### Execute the first Python script as below

# %%
#my first python script
print("Hello my friend. Thank for reviewing my assignment:)")
# Out:
# Hello my friend. Thank for reviewing my assignment:)

# %% [markdown]
# This is a bulletet list:
# - item 1
# - item 2
# - item 3
#
# This is a numbered list:
# 1. item 1
# 2. item 2
# 3. item 3
#
# You can find eveything on [google](www.google.com)
